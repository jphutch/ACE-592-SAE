# %% [markdown]
# # Wildfires in the US
# ## An Application of Geopandas, Rasterio, and Zonalstats

# %%
import numpy
import matplotlib.pyplot as plt
import geopandas
import pyproj
import rasterio
import rasterstats

# %%
data_dir = "C:/Users/jhtchns2/Box/ACE 592 SAE/Class_Examples/2_Images/"

# %% [markdown]
# The objective of this lecture is to demonstrate how to:
# 1. Read shape files.
# 2. Read and edit rasters.
# 3. Calculate zonal stats from:
#     - A raster and a shape file
#     - A shape file and a shape file

# %% [markdown]
# ## Step 1: Reading shape files
#
# ### US States
# Below is a geojson file of US states which is read into the dataframe as a geopandas dataframe

# %%
state_file = data_dir + "us_states.json"

country = geopandas.read_file(state_file)

# %% [markdown]
# What is a geopandas dataframe?
#
# Essentially, it is the same as a pandas dataframe but with geographic methods. For example:
# - It has a column called "geometry" which stores a `shapely` polygon or multi-polygon object.
# - Has geographic information embedded (like the CRS).
# - Default plot method makes a spatial plot.

# %%
country.head()
# Out:
#         GEO_ID STATE        NAME LSAD  CENSUSAREA  \
# 0  0400000US01    01     Alabama        50645.326
# 1  0400000US02    02      Alaska       570640.950
# 2  0400000US04    04     Arizona       113594.084
# 3  0400000US05    05    Arkansas        52035.477
# 4  0400000US06    06  California       155779.220
#
#                                             geometry
# 0  MULTIPOLYGON (((-88.12466 30.28364, -88.08681 ...
# 1  MULTIPOLYGON (((-166.10574 53.98861, -166.0752...
# 2  POLYGON ((-112.53859 37.00067, -112.53454 37.0...
# 3  POLYGON ((-94.04296 33.01922, -94.04304 33.079...
# 4  MULTIPOLYGON (((-122.42144 37.86997, -122.4213...

# %%
print(type(country['geometry'][4]))
country['geometry'][2]
# Out:
# <class 'shapely.geometry.multipolygon.MultiPolygon'>
# <POLYGON ((-112.539 37.001, -112.535 37.001, -112.369 37.001, -112.358 37.00...>

# %%
country.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
country.plot()
# Out:
# <Axes: >

# %% [markdown]
# The frame is a bit big. What if we just wanted to look at the continental US?
#
# Do what you would do usually with a Pandas dataframe!

# %%
country = country[~country['NAME'].isin(["Alaska","Hawaii","Puerto Rico"])]

country.plot(color="Grey")
# Out:
# <Axes: >

# %% [markdown]
# These dataframes have very useful methods and attributes:
# - `centroid`, which can extract the centroid from the shape.
# - `to_crs()`, which can change the projection.
# - `distance()`, which can tell you the distance between each row and a specific geometry.
#
# Let's use these methods to find the distance between the Alabama centroid and every other state centroid.

# %%
f,a = plt.subplots()
country.plot(ax=a)
country.centroid.plot(ax=a,color="white")
# Out:
# C:\Users\jhtchns2\AppData\Local\Temp\ipykernel_23692\995934108.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   country.centroid.plot(ax=a,color="white")
# <Axes: >

# %% [markdown]
# User warning! What did we do wrong?

# %%
country_proj = country.to_crs(epsg=4087) # WGS 84 Equidistant Cylndrical
country_proj.plot()
# Out:
# <Axes: >

# %%
country_proj.centroid
# Out:
# 0      POINT (-9665692.036 3650141.472)
# 2     POINT (-12430444.498 3817508.335)
# 3     POINT (-10290293.085 3885021.352)
# 4     POINT (-13314999.483 4146226.165)
# 5     POINT (-11749529.566 4341298.650)
# 6      POINT (-8095771.713 4633214.781)
# 7      POINT (-8404641.201 4340544.764)
# 8      POINT (-8573415.271 4330854.407)
# 9      POINT (-9183945.172 3188092.865)
# 10     POINT (-9289173.025 3634478.976)
# 12    POINT (-12763817.801 4941374.665)
# 13     POINT (-9929507.380 4459986.934)
# 14     POINT (-9604106.094 4442574.226)
# 15    POINT (-10408376.567 4683725.267)
# 16    POINT (-10951635.523 4284097.122)
# 17     POINT (-9494494.026 4177448.883)
# 18    POINT (-10239408.762 3456672.896)
# 19     POINT (-7706221.893 5050714.556)
# 20     POINT (-8545304.690 4344772.546)
# 21     POINT (-7992408.236 4703567.193)
# 22     POINT (-9510888.544 4937384.071)
# 23    POINT (-10498400.783 5155921.687)
# 24     POINT (-9981475.057 3645761.912)
# 25    POINT (-10294539.501 4271063.430)
# 26    POINT (-12205633.187 5235750.606)
# 27    POINT (-11110887.881 4622780.707)
# 28    POINT (-12986019.290 4381140.992)
# 29     POINT (-7967988.044 4863072.515)
# 30     POINT (-8311243.191 4473244.919)
# 31    POINT (-11811930.688 3831768.866)
# 32     POINT (-8404881.810 4780032.586)
# 33     POINT (-8833906.759 3956262.441)
# 34    POINT (-11184192.936 5281701.966)
# 35     POINT (-9216160.828 4485458.152)
# 36    POINT (-10854589.964 3961136.648)
# 37    POINT (-13420149.878 4891015.686)
# 38     POINT (-8660604.274 4550052.481)
# 39     POINT (-7965232.344 4639407.330)
# 40     POINT (-9005235.687 3774403.237)
# 41    POINT (-11157607.048 4946609.816)
# 42     POINT (-9611691.182 3990023.128)
# 43    POINT (-11060154.320 3505474.319)
# 44    POINT (-12431960.899 4377504.154)
# 45     POINT (-8088776.599 4906426.827)
# 46     POINT (-8772559.124 4176184.575)
# 47    POINT (-13408686.935 5274538.761)
# 48     POINT (-8973893.229 4301664.543)
# 49    POINT (-10020028.362 4969210.205)
# 50    POINT (-11972572.233 4786697.515)
# dtype: geometry

# %%
f,a = plt.subplots(figsize=(10,4))
country_proj.plot(ax=a,zorder=1,color='gray')
country_proj.centroid.plot(ax=a,color="white",markersize=5)
# Out:
# <Axes: >

# %% [markdown]
# The `distance` function works on a series, but requires a geometry object to be passed right to the function.

# %%
bama_cent = country_proj.centroid[0]

# %%
country_proj['bama_dist'] = country_proj.centroid.distance(bama_cent)/1000 # res is in meters, so converting to km
country_proj.sort_values("bama_dist").head()
# Out:
#          GEO_ID STATE         NAME LSAD  CENSUSAREA  \
# 0   0400000US01    01      Alabama        50645.326
# 24  0400000US28    28  Mississippi        46923.274
# 42  0400000US47    47    Tennessee        41234.896
# 10  0400000US13    13      Georgia        57513.485
# 17  0400000US21    21     Kentucky        39486.338
#
#                                              geometry   bama_dist
# 0   MULTIPOLYGON (((-9809992.055 3371159.384, -980...    0.000000
# 24  MULTIPOLYGON (((-9918079.384 3365384.908, -991...  315.813389
# 42  POLYGON ((-9292072.558 4073991.019, -9281251.8...  344.144784
# 10  POLYGON ((-9441059.114 3894802.595, -9440915.1...  376.844636
# 17  MULTIPOLYGON (((-9961436.434 4062904.489, -996...  554.402258

# %%
f,a = plt.subplots(figsize=(15,5))
country_proj.plot(column="bama_dist", # The data it uses to assign colors
                  ax=a,\
                  legend=True,\
                  legend_kwds={'label': "Centroid Distance (km)"});
country_proj.centroid[:1].plot(color="C3",ax=a,markersize=60);
country_proj.centroid[1:].plot(color="w",ax=a,markersize=5);

plt.axis("off");

plt.title("State Centroid Distance from Alabama",fontsize=18)
# Out:
# Text(0.5, 1.0, 'State Centroid Distance from Alabama')

# %% [markdown]
# ### Notice:
# Some cool functionality of the plotting function is that it has built in ability to do chloropleth maps very easily!
#
# Going back to the code that I just wrote:

# %%
f,a = plt.subplots(figsize=(7,6))
country_proj.plot(column="bama_dist", # the column argument colors states by the value of that column.
                  ax=a,
                  cmap="copper", # set your own colormap.
                  legend=True, # setting the legend as true leads to a color bar being plotted.
                  legend_kwds={'label': "Centroid Distance (km)",# this labels it.
                               'orientation': "horizontal"}); # this changes the orientation.
plt.axis("off");
plt.savefig("war_eagle_roll_tide.png",dpi=300)

# %% [markdown]
# ## Wildfires
# To demonstrate spatial joins, let's say we want to look at wildfires. NASA keeps a very [nice database on active fires](https://firms.modaps.eosdis.nasa.gov/active_fire/#firms-shapefile).
#
# This one is a shapefile from NASA which was collected using their MODIS instrument. These are all the fires from October 20th 2020 until October 27th 2020.

# %%
fires = geopandas.read_file(data_dir+"MODIS_C6_USA_contiguous_and_Hawaii_7d.shp")

# %% [markdown]
# Before we go plotting them together, let's do a projection check.
#
# #### Projection check

# %%
country.crs == fires.crs
# Out:
# True

# %% [markdown]
# We're good to go!

# %% [markdown]
# Notice that instead of "polygons," we have "point" objects.
#
# If we plot them on top of each other we get this:

# %%
f,a = plt.subplots(figsize=(10,10))
country.plot(ax=a,color="grey")
fires.plot(color="C3",markersize=10,ax=a)
# Out:
# <Axes: >

# %% [markdown]
# So notice that our fire data is in Mexico as well as Canada. How do we only look at fires in the US?
#
# Intuitively, we look for the overlap. Restricting a shape file based on another shapefile is called __clipping__.
#
# Geopandas has a great clipping function:

# %%
print(fires.shape)
print(geopandas.clip(fires,country).shape)
# Out:
# (3872, 14)
# (3310, 14)

# %% [markdown]
# The first argument is the thing you want clipped, the second argument is the mask used to clip it.
#
# So it looks like clipping got rid of about 500 fires.

# %%
fires = geopandas.clip(fires,country)

f,a = plt.subplots(figsize=(10,10))
country.plot(ax=a,color="grey")
fires.plot(color="C3",markersize=10,ax=a);

# %% [markdown]
# Using the geopandas plotting function, we can actually color the dots according to one of the variables.
#
# We will do it here according to the column "brightness."

# %%
f,a = plt.subplots(figsize=(10,5))

country.plot(ax=a,color="grey")

geopandas.clip(fires,country).plot(markersize=10, # set the markersize 
                                   ax=a, # use the current axis we created
                                   column='BRIGHTNESS', #column to use
                                   cmap="OrRd_r", # colormap to use
                                   scheme='quantiles', # this keyword breaks the categories on quantiles.
                                   legend=True); # show a legend

# %% [markdown]
# ### What is a spatial join?
# Spatial joining is essentially executing a merge between two shapefiles. Instead of using indexes it uses their spatial positions.
#
# For example, what if we wanted to count the number of fires in a given state?

# %%
fires_w_state = geopandas.sjoin(fires,\
                                country,\
                                how='left')

state_w_fires = geopandas.sjoin(fires,\
                                country,\
                                how='right')

fires_w_state.shape, state_w_fires.shape
# Out:
# ((3310, 20), (3322, 20))

# %% [markdown]
# They look about the same size, what was the difference between the left and right merge?

# %%
fires_w_state.head().geometry, state_w_fires.head().geometry
# Out:
# (3226    POINT (-90.83200 29.58800)
#  3227    POINT (-90.88600 29.80200)
#  3228    POINT (-90.96800 29.80900)
#  3358    POINT (-90.95600 29.81600)
#  1025    POINT (-90.79100 29.81700)
#  Name: geometry, dtype: geometry,
#  0    MULTIPOLYGON (((-88.12466 30.28364, -88.08681 ...
#  0    MULTIPOLYGON (((-88.12466 30.28364, -88.08681 ...
#  0    MULTIPOLYGON (((-88.12466 30.28364, -88.08681 ...
#  0    MULTIPOLYGON (((-88.12466 30.28364, -88.08681 ...
#  0    MULTIPOLYGON (((-88.12466 30.28364, -88.08681 ...
#  Name: geometry, dtype: geometry)

# %% [markdown]
# With spatial joins in geopandas dataframes, only one set of geometry will be retained. So make sure you understand how you are merging things!

# %% [markdown]
# Both of these dataframes could be useful in different ways.

# %%
f,a = plt.subplots(figsize=(10,10))
country.plot(color='gray',ax=a)
fires_w_state.plot(column="CENSUSAREA",ax=a)
plt.title("Fires Colored by Census Area")
# Out:
# Text(0.5, 1.0, 'Fires Colored by Census Area')

# %% [markdown]
# Let's get a count of fires per state.

# %%
state_w_fires.value_counts("NAME").head()
# Out:
# NAME
# Colorado      1221
# California     722
# Louisiana      200
# Alabama        155
# Georgia        142
# Name: count, dtype: int64

# %%
state_fire_counts = state_w_fires.groupby("NAME")['index_left'].count().reset_index()

state_fire_counts.columns = ["NAME","fire_number"]

state_fire_counts.head()
# Out:
#          NAME  fire_number
# 0     Alabama          155
# 1     Arizona           65
# 2    Arkansas           88
# 3  California          722
# 4    Colorado         1221

# %%
country = country.merge(state_fire_counts,how='left',on="NAME")

# %%
f,a = plt.subplots(figsize=(20,10))
country.plot(column="fire_number",
             ax=a,
             cmap="OrRd",
            legend=True)
country.plot(ax=a,facecolor='none', edgecolor='black')
# Out:
# <Axes: >

# %% [markdown]
# California and Colorado are clear outliers, could use the quantile method instead.

# %%
f,a = plt.subplots(figsize=(10,10))
country
country.plot(column="fire_number",
             ax=a,
             cmap="OrRd",
            scheme="quantiles",
            legend=True)

country.plot(ax=a,facecolor='none', edgecolor='black')
# Out:
# <Axes: >

# %% [markdown]
# ### Dissolves
#
# What if we wanted to merge polygons into one polygons? This is called a __dissolve__.
#
# Geopandas make this very easy.

# %%
country['country'] = "USA"

country.dissolve(by="country",aggfunc="sum").plot(edgecolor="black")
# Out:
# <Axes: >

# %% [markdown]
# Or do it based on something arbitrary:

# %%
country.loc[30:,"country"] = "Not USA"
country.dissolve(by="country",aggfunc="sum").plot(edgecolor="black")
# Out:
# <Axes: >

# %% [markdown]
# So now we have dissolved all of the states into one polygon. Dissolves are useful when you want to change the level of analysis.

# %% [markdown]
# ## Step 2: Read in rasters

# %% [markdown]
#  Let's read in a raster file, in this case annual precipitation data from 2017 from [PRISM](https://prism.oregonstate.edu/recent/), a great source of historical weather data.
#
#  The package for reading in raster files is called `rasterio`

# %%
import rasterio

raster_file = "PRISM_ppt_stable_4kmM3_2017_bil.bil"

raster = rasterio.open(data_dir+raster_file)

# %%
plt.imshow(raster.read()[0,:,:])

# %% [markdown]
# In this case, the file format is a .bil not a .tif

# %% [markdown]
# #### Projection check:

# %%
raster.crs==country_proj.crs
# Out:
# False

# %% [markdown]
# What are the CRSs?

# %%
raster.crs#,country_proj.crs
# Out:
# CRS.from_wkt('GEOGCS["NAD83",DATUM["North_American_Datum_1983",SPHEROID["GRS 1980",6378137,298.257222101,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6269"]],PRIMEM["Greenwich",0],UNIT["Degree",0.0174532925199433],AXIS["Longitude",EAST],AXIS["Latitude",NORTH]]')

# %% [markdown]
# So this is not what our shapefile currently is because we reprojected it...
#
# Two ways we can go about this:
# 1. Reproject the raster file to match the shapefile (harder).
# 2. Reproject the shapefile to match the raster (easier).
#
# It takes only one line to reproject geopandas dataframes, but much more code to do the same for rasterio. Here I'll demonstrate the raster way.

# %% [markdown]
# So what is the raster object anyway?

# %%
raster.width,raster.height,raster.bounds
# Out:
# (1405,
#  621,
#  BoundingBox(left=-125.0208333333335, bottom=24.0624999997925, right=-66.4791666661985, top=49.9374999999995))

# %% [markdown]
# Notice that it is almost the same as a numpy array but it embeds geographic information. The function `read` will transform it into a numpy array.

# %%
type(raster.read()),raster.read().shape
# Out:
# (numpy.ndarray, (1, 621, 1405))

# %% [markdown]
# How can we use this info to translate it into a different coordinate system?

# %%
raster.transform
# Out:
# Affine(0.041666666667, 0.0, -125.0208333333335,
#        0.0, -0.041666666667, 49.9374999999995)

# %% [markdown]
# Each raster contains an "affine transformation" which translates the pixel coordinates into geographic coordinates.
#
# According to the docs, the above are coefficients to this equation:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Reprojecting a Raster
#
# Essentially, we need to create a function that translates one "transformation" into another. We need to take the measurements of the first system and create a function that translates into a new system.
#
# Now let's look at some code from [this question](https://gis.stackexchange.com/questions/337528/rasterio-reprojection-doesnt-seem-to-work]):

# %%
import numpy as np
import rasterio
from rasterio.warp import calculate_default_transform, reproject, Resampling
import geopandas

src_file = raster_file
dst_file = 'ppt_reproj.tif'
dst_crs = rasterio.crs.CRS.from_dict({'init': 'EPSG:4087'})

# %% [markdown]
# The following code does the reprojection... but what is it actually doing?

# %%
with rasterio.open(data_dir+src_file) as src: 
    transform, width, height = calculate_default_transform(
        src.crs, dst_crs, src.width, src.height, *src.bounds) 
    kwargs = src.meta.copy() 
    kwargs.update({
        'crs': dst_crs,
        'transform': transform,
        'width': width,
        'height': height
    })
    with rasterio.open(dst_file, 'w', **kwargs) as dst: 
        for i in range(1, src.count + 1):
            reproject(
                source=rasterio.band(src, i),
                destination=rasterio.band(dst, i),
                src_transform=src.transform,
                src_crs=src.crs,
                dst_transform=transform,
                dst_crs=dst_crs,
                resampling=Resampling.nearest)

# %% [markdown]
# ### Discuss in groups!

# %%
raster = rasterio.open("./ppt_reproj.tif")

raster.crs
# Out:
# CRS.from_epsg(4087)

# %%
ppt = raster.read(1)

ppt
# Out:
# array([[-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        ...,
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.]],
#       dtype=float32)

# %% [markdown]
# So now we have a Numpy array. Here's what it looks like plotted:

# %%
plt.imshow(ppt,cmap="Blues")

# %% [markdown]
# ##### Reminder
#
# the difference between a raster and a usual numpy array is that rasters are georeferenced. So rasters have info like this:

# %%
raster.crs
# Out:
# CRS.from_epsg(4087)

# %%
raster.bounds
# Out:
# BoundingBox(left=-13917255.50521741, bottom=2678625.659265449, right=-7400426.981642393, top=5559017.483564442)

# %% [markdown]
# But reading it as a numpy array it no longer has this data, it's simply a matrix.
#    [-10025362.875604546, 4231870.888989795],
#    [-10025994.947673269, 4232019.166551532],
#    [-10026800.67814763, 4232033.192807372],
#    [-10027766.486049753, 4231858.087248354],
#    [-10028579.229652036, 4231896.381153187],
#    [-10029193.04532427, 4232125.810623712],
#    [-10031057.201517094, 4233095.8486664845],
#    [-10031825.63996204, 4233670.368558469],
#    [-10032802.023215787, 4234671.576058663],
#    [-10032848.554762939, 4235036.592668975],
#    [-10032781.095151518, 4235770.076793811],
#    [-10032824.509752927, 4236251.7562304735],
#    [-10033020.766015196, 4236780.18985327],
#    [-10033313.424956493, 4237080.41851994],
#    [-10034845.737747261, 4237824.25535742],
#    [-10036401.984228551, 4238460.112288831],
#    [-10036739.170966165, 4238477.366809904],
#    [-10036945.00070464, 4238416.920326403],
#    [-10037925.614099039, 4237892.4942052765],
#    [-10041762.129029738, 4239933.314429989],
#    [-10043100.634587036, 4240645.313893103],
#    [-10045817.720718319, 4242682.905852582],
#    [-10046597.179792853, 4244061.597746057],
#    [-10046860.56170807, 4244341.788904385],
#    [-10046880.710535904, 4244368.728221157],
#    [-10049359.016359435, 4247686.271685777],
#    [-10050267.71736278, 4248446.806446877],
#    [-10051121.983135127, 4249115.391308581],
#    [-10052204.565183092, 4249648.945627954],
#    [-10053333.344819736, 4250019.194254332],
#    [-10054024.52753807, 4250117.600684194],
#    [-10054638.343210306, 4250355.490436018],
#    [-10055662.593845095, 4251021.960227397],
#    [-10055963.6017482, 4251283.783669744],
#    [-10058150.361825343, 4253946.879847991],
#    [-10058403.502347408, 4254352.750711423],
#    [-10058780.09618476, 4255134.658814755],
#    [-10059266.228401054, 4256451.56839084],
#    [-10059609.871669132, 4257976.534095217],
#    [-10059693.472606717, 4258616.95512575],
#    [-10060041.67997392, 4259912.04608164],
#    [-10060150.439116426, 4260633.952979434],
#    [-10060379.75726746, 4261516.382582951],
#    [-10060367.512123471, 4262919.119486438],
#    [-10060133.741192807, 4264021.182445291],
#    [-10060222.79678544, 4266136.252770364],
#    [-10060033.553651093, 4267271.711576455],
#    [-10059744.122975029, 4268017.55216477],
#    [-10058419.309715098, 4270255.073929715],
#    [-10057687.384063134, 4272175.891743354],
#    [-10057283.850909008, 4272648.33166228],
#    [-10056949.892436627, 4273049.081829135],
#    ...]]}

# %% [markdown]
# This is the data we need to load into the function, so we can make a fancy function (this is from [this documentation](https://automating-gis-processes.github.io/CSC18/lessons/L6/clipping-raster.html)):
#
# Essentially, this function takes a GeoDataFrame and extracts the coordinates it needs.

# %%
def getFeatures(gdf):
    """Function to parse features from GeoDataFrame in such a manner that rasterio wants them"""
    import json
    return [json.loads(gdf.to_json())['features'][0]['geometry']]

IL_row = country_proj[country_proj.NAME=="Illinois"]

IL_coords = getFeatures(IL_row)

# %% [markdown]
# What they look like plotted:

# %%
coords = np.array(IL_coords[0]['coordinates'][0])
plt.plot(coords[:,0],coords[:,1],color='black')

# %% [markdown]
# Rasterio has its own `mask` function that can help us with this. It takes the raster object as the first argument and our coordinates as the second:

# %%
from rasterio.mask import mask

img_out, img_transform = mask(raster,IL_coords)

# %% [markdown]
# Plotted it looks like this:

# %%
plt.imshow(img_out[0],cmap="Blues")

# %% [markdown]
# So now we have just Illinois. But notice now that the indices dont have anything to do with geo-coordinates. How do we get this info back?
#
# The second output of the function "mask" is the directions on how to translate them back:

# %%
img_transform
# Out:
# Affine(4638.3121164235, 0.0, -13917255.50521741,
#        0.0, -4638.3121164235, 5559017.483564442)

# %% [markdown]
# To make this a raster again, we can write it back as a raster while re-embedding the metadata

# %%
out_meta = raster.meta.copy()

out_meta['height'] = img_out.shape[1]
out_meta['width'] = img_out.shape[2]
out_meta['transform'] = img_transform

with rasterio.open("./IL_PPT.tif", "w", **out_meta) as dest:
    dest.write(img_out)

# %%
IL_raster = rasterio.open("./IL_PPT.tif")

# %%
IL_raster.read(1)
# Out:
# array([[-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        ...,
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.]],
#       dtype=float32)

# %%
from rasterio.plot import show

fig, ax = plt.subplots(figsize=(15, 15))
rasterio.plot.show(IL_raster, ax=ax,cmap="Blues")
country_proj.plot(ax=ax, facecolor='none', edgecolor='black')
# Out:
# <Axes: >

# %% [markdown]
# Nice!
#
# With this technique, a huge upside is that __we can edit rasters just like numpy arrays__ as long as we write the data back with the right metadata.
#
# For example, what if we wanted a raster of zeros and ones indicating if rainfall hits a certain threshhold, for example the state average?

# %% [markdown]
# ### Making a New Raster

# %%
import pandas as pd
IL_vals = pd.Series(IL_raster.read(1).flatten())

IL_avg = IL_vals[IL_vals!=-9999].mean()

# %%
IL_avg
# Out:
# 973.25

# %% [markdown]
# Do it like this:

# %%
IL_r_vals = IL_raster.read(1)

# %%
img_out = (IL_r_vals>IL_avg)[np.newaxis,:,:].astype(np.float32)

# %% [markdown]
# __NOTE:__ A couple of things happened up there:
#
# `img_out = (IL_r_vals>IL_avg)[np.newaxis,:,:].astype(np.float32)`
#
# 1. We made a boolean array by coding "True" if the rainfall was above the average
# 2. We added an axis so the array is three dimensions using "np.newaxis"; raster always are three dimensional arrays, the first dimension being the band and the second and third being the rows and the columns. We need to put a "band" dimension into any array before it can be written to raster.
# 3. We converted the "booleans" to float32 to make it play nice with Rasterio

# %% [markdown]
# Now change the metadata

# %%
out_meta = IL_raster.meta.copy()

out_meta['height'] = img_out.shape[1]
out_meta['width'] = img_out.shape[2]
out_meta['transform'] = img_transform

with rasterio.open("./example.tif", "w", **out_meta) as dest:
    dest.write(img_out)

# %%
IL_raster = rasterio.open("./example.tif")

fig, ax = plt.subplots(figsize=(3, 5))
rasterio.plot.show(IL_raster, ax=ax,cmap="Blues")
country_proj.plot(ax=ax, facecolor='none', edgecolor='black')
plt.xlim(-1.03*10**7,-.97*10**7)
plt.ylim(4.1*10**6,4.8*10**6)
# Out:
# (4099999.9999999995, 4800000.0)

# %% [markdown]
# ### The above is an important skill for Homework 2

# %% [markdown]
# ## Step 3: Zonal Statistics
#
# The next step is doing some basic zonal statistics. Zonal statistics are one way to summarize a raster file using a vector file.
#
# Here we will find the average rainfall for that year for all the counties in Illinois.
#
# ### Country-wide
#
# First, let's start with the whole country.
#
# The package "rasterstats" is very convenient for this. Its function "zonal_stats" takes two arguments:
# 1. Shapefile path, polygon object, or geopandas dataframe
# 2. Raster file path, or a numpy array if you supply "transform" to tell it coordinates.

# %%
from rasterstats import zonal_stats

zonal_stats(country_proj, "./ppt_reproj.tif")
# Out:
# [{'min': 1148.89208984375,
#   'max': 2756.134033203125,
#   'mean': 1706.3798710024187,
#   'count': 7442},
#  {'min': 58.06500244140625,
#   'max': 983.2120361328125,
#   'mean': 241.176297276171,
#   'count': 16631},
#  {'min': 834.4190673828125,
#   'max': 1702.319091796875,
#   'mean': 1307.564802885854,
#   'count': 7762},
#  {'min': 35.570003509521484,
#   'max': 5572.697265625,
#   'mean': 761.2146278478904,
#   'count': 24009},
#  {'min': 133.68701171875,
#   'max': 1926.1900634765625,
#   'mean': 509.372574385511,
#   'count': 16233},
#  {'min': 1059.968017578125,
#   'max': 1371.3480224609375,
#   'mean': 1179.953164160401,
#   'count': 798},
#  {'min': 1024.3670654296875,
#   'max': 1418.944091796875,
#   'mean': 1179.0415023659307,
#   'count': 317},
#  {'min': 978.2060546875,
#   'max': 1113.2880859375,
#   'mean': 1036.1656605113637,
#   'count': 11},
#  {'min': 917.1100463867188,
#   'max': 2640.752197265625,
#   'mean': 1600.7582706766918,
#   'count': 7980},
#  {'min': 925.6790161132812,
#   'max': 2125.67822265625,
#   'mean': 1311.4513798412886,
#   'count': 8443},
#  {'min': 174.8090057373047,
#   'max': 2433.842041015625,
#   'mean': 754.185243104919,
#   'count': 14068},
#  {'min': 714.2110595703125,
#   'max': 1379.985107421875,
#   'mean': 973.2500281309779,
#   'count': 8887},
#  {'min': 869.3970336914062,
#   'max': 1557.8861083984375,
#   'mean': 1191.8281084889045,
#   'count': 5678},
#  {'min': 610.1390380859375,
#   'max': 1219.569091796875,
#   'mean': 834.9736612498637,
#   'count': 9169},
#  {'min': 426.1670227050781,
#   'max': 1468.85205078125,
#   'mean': 779.5840404826781,
#   'count': 12845},
#  {'min': 899.1880493164062,
#   'max': 1582.967041015625,
#   'mean': 1297.5436766623206,
#   'count': 6136},
#  {'min': 912.2080688476562,
#   'max': 2615.43505859375,
#   'mean': 1660.0911399970119,
#   'count': 6693},
#  {'min': 815.5970458984375,
#   'max': 1788.3770751953125,
#   'mean': 1174.9430244941427,
#   'count': 5634},
#  {'min': 792.9150390625,
#   'max': 1604.505126953125,
#   'mean': 1114.2843137254902,
#   'count': 1632},
#  {'min': 1041.5550537109375,
#   'max': 1566.132080078125,
#   'mean': 1222.9475412912914,
#   'count': 1332},
#  {'min': 806.529052734375,
#   'max': 1425.1370849609375,
#   'mean': 1042.0263854930724,
#   'count': 9816},
#  {'min': 314.9300231933594,
#   'max': 1242.4210205078125,
#   'mean': 742.8296913411637,
#   'count': 14644},
#  {'min': 1010.153076171875,
#   'max': 2849.4521484375,
#   'mean': 1564.7146412884333,
#   'count': 6830},
#  {'min': 692.8470458984375,
#   'max': 1580.5860595703125,
#   'mean': 1085.0262325581396,
#   'count': 10750},
#  {'min': 97.14700317382812,
#   'max': 2678.88623046875,
#   'mean': 459.61127447187187,
#   'count': 25846},
#  {'min': 374.3880310058594,
#   'max': 1195.8651123046875,
#   'mean': 668.1970507211149,
#   'count': 12342},
#  {'min': 41.69900131225586,
#   'max': 2417.1181640625,
#   'mean': 292.48332069749813,
#   'count': 17147},
#  {'min': 1035.072021484375,
#   'max': 2066.110107421875,
#   'mean': 1318.2937378954164,
#   'count': 1549},
#  {'min': 1013.2200317382812,
#   'max': 1437.5030517578125,
#   'mean': 1187.5686936936936,
#   'count': 1221},
#  {'min': 172.302001953125,
#   'max': 1223.3690185546875,
#   'mean': 405.9312616112143,
#   'count': 17763},
#  {'min': 833.2450561523438,
#   'max': 2006.8560791015625,
#   'mean': 1259.1320335636722,
#   'count': 8104},
#  {'min': 763.14306640625,
#   'max': 2261.467041015625,
#   'mean': 1272.3795885437676,
#   'count': 7437},
#  {'min': 158.98500061035156,
#   'max': 657.81201171875,
#   'mean': 360.6425166825548,
#   'count': 12588},
#  {'min': 884.3980712890625,
#   'max': 1485.986083984375,
#   'mean': 1171.597305160006,
#   'count': 6531},
#  {'min': 536.7850341796875,
#   'max': 1547.705078125,
#   'mean': 971.2993815229996,
#   'count': 10348},
#  {'min': 172.416015625,
#   'max': 6110.4130859375,
#   'mean': 965.0970993117011,
#   'count': 16272},
#  {'min': 879.666015625,
#   'max': 1873.695068359375,
#   'mean': 1188.730914166085,
#   'count': 7165},
#  {'min': 1026.14404296875,
#   'max': 1396.0140380859375,
#   'mean': 1277.7605317679559,
#   'count': 181},
#  {'min': 902.89404296875,
#   'max': 2099.670166015625,
#   'mean': 1257.0203924162258,
#   'count': 4536},
#  {'min': 228.14601135253906,
#   'max': 865.8700561523438,
#   'mean': 467.3034194587135,
#   'count': 13043},
#  {'min': 865.4940185546875,
#   'max': 2118.05615234375,
#   'mean': 1451.5056179775281,
#   'count': 6319},
#  {'min': 179.41900634765625,
#   'max': 2921.028076171875,
#   'mean': 800.0358806462775,
#   'count': 37569},
#  {'min': 95.6820068359375,
#   'max': 1929.757080078125,
#   'mean': 342.27845651843984,
#   'count': 13178},
#  {'min': 962.4430541992188,
#   'max': 1792.696044921875,
#   'mean': 1253.8858528325122,
#   'count': 1624},
#  {'min': 739.0640258789062,
#   'max': 1622.0841064453125,
#   'mean': 1071.2151826484019,
#   'count': 6132},
#  {'min': 198.93101501464844,
#   'max': 8375.4140625,
#   'mean': 1291.7358303770316,
#   'count': 12121},
#  {'min': 772.5460205078125,
#   'max': 1739.3050537109375,
#   'mean': 1216.9039797008547,
#   'count': 3744},
#  {'min': 692.7640380859375,
#   'max': 1308.5350341796875,
#   'mean': 984.828934917464,
#   'count': 9511},
#  {'min': 172.7860107421875,
#   'max': 2616.62109375,
#   'mean': 500.11865352427003,
#   'count': 16131}]

# %% [markdown]
# Returns a list of dictionaries that can be made into a dataframe:

# %%
import pandas as pd
rain_stats = pd.DataFrame(zonal_stats(country_proj, "./ppt_reproj.tif"))

rain_stats.shape
# Out:
# (49, 4)

# %% [markdown]
# Notice there are 49 rows, which is the same as `country_proj`:

# %%
country_proj.shape
# Out:
# (49, 7)

# %% [markdown]
# This function calculates stats and returns the stats unlabeled but in the same order as the input shapefile.
#
# This means we just concatenate our dataframes:

# %%
rain_stats.columns = ["rain_"+x for x in rain_stats.columns]

# Note: you need to make the indices match first
rain_stats.index = country_proj.index

country_rain = pd.concat([country_proj,rain_stats],axis=1)

# %%
country_rain
# Out:
#          GEO_ID STATE                  NAME LSAD  CENSUSAREA  \
# 0   0400000US01    01               Alabama        50645.326
# 2   0400000US04    04               Arizona       113594.084
# 3   0400000US05    05              Arkansas        52035.477
# 4   0400000US06    06            California       155779.220
# 5   0400000US08    08              Colorado       103641.888
# 6   0400000US09    09           Connecticut         4842.355
# 7   0400000US10    10              Delaware         1948.543
# 8   0400000US11    11  District of Columbia           61.048
# 9   0400000US12    12               Florida        53624.759
# 10  0400000US13    13               Georgia        57513.485
# 12  0400000US16    16                 Idaho        82643.117
# 13  0400000US17    17              Illinois        55518.930
# 14  0400000US18    18               Indiana        35826.109
# 15  0400000US19    19                  Iowa        55857.130
# 16  0400000US20    20                Kansas        81758.717
# 17  0400000US21    21              Kentucky        39486.338
# 18  0400000US22    22             Louisiana        43203.905
# 19  0400000US23    23                 Maine        30842.923
# 20  0400000US24    24              Maryland         9707.241
# 21  0400000US25    25         Massachusetts         7800.058
# 22  0400000US26    26              Michigan        56538.901
# 23  0400000US27    27             Minnesota        79626.743
# 24  0400000US28    28           Mississippi        46923.274
# 25  0400000US29    29              Missouri        68741.522
# 26  0400000US30    30               Montana       145545.801
# 27  0400000US31    31              Nebraska        76824.171
# 28  0400000US32    32                Nevada       109781.180
# 29  0400000US33    33         New Hampshire         8952.651
# 30  0400000US34    34            New Jersey         7354.220
# 31  0400000US35    35            New Mexico       121298.148
# 32  0400000US36    36              New York        47126.399
# 33  0400000US37    37        North Carolina        48617.905
# 34  0400000US38    38          North Dakota        69000.798
# 35  0400000US39    39                  Ohio        40860.694
# 36  0400000US40    40              Oklahoma        68594.921
# 37  0400000US41    41                Oregon        95988.013
# 38  0400000US42    42          Pennsylvania        44742.703
# 39  0400000US44    44          Rhode Island         1033.814
# 40  0400000US45    45        South Carolina        30060.696
# 41  0400000US46    46          South Dakota        75811.000
# 42  0400000US47    47             Tennessee        41234.896
# 43  0400000US48    48                 Texas       261231.711
# 44  0400000US49    49                  Utah        82169.620
# 45  0400000US50    50               Vermont         9216.657
# 46  0400000US51    51              Virginia        39490.086
# 47  0400000US53    53            Washington        66455.521
# 48  0400000US54    54         West Virginia        24038.210
# 49  0400000US55    55             Wisconsin        54157.805
# 50  0400000US56    56               Wyoming        97093.141
#
#                                              geometry    bama_dist  \
# 0   MULTIPOLYGON (((-9809992.055 3371159.384, -980...     0.000000
# 2   POLYGON ((-12527738.867 4118896.189, -12527288...  2769.813683
# 3   POLYGON ((-10468814.865 3675682.645, -10468822...   667.304299
# 4   MULTIPOLYGON (((-13627892.252 4215665.665, -13...  3682.871823
# 5   POLYGON ((-11821078.398 4563832.735, -11806676...  2195.467397
# 6   POLYGON ((-7992655.059 4676316.405, -7992508.1...  1852.318264
# 7   MULTIPOLYGON (((-8411849.195 4406387.011, -841...  1437.673785
# 8   POLYGON ((-8575897.501 4318251.474, -8575930.8...  1287.027052
# 9   MULTIPOLYGON (((-9219656.669 3112987.555, -922...   667.509519
# 10  POLYGON ((-9441059.114 3894802.595, -9440915.1...   376.844636
# 12  POLYGON ((-12361378.901 4788970.283, -12361375...  3356.436564
# 13  POLYGON ((-9948181.065 4731108.860, -9947683.4...   851.732474
# 14  POLYGON ((-9440169.226 4511561.444, -9440176.3...   794.822305
# 15  POLYGON ((-10154308.583 4842459.075, -10154371...  1272.743404
# 16  POLYGON ((-11080866.346 4118773.626, -11082753...  1433.719085
# 17  MULTIPOLYGON (((-9961436.434 4062904.489, -996...   554.402258
# 18  MULTIPOLYGON (((-9892414.008 3312056.972, -989...   605.459306
# 19  MULTIPOLYGON (((-7809350.485 4869870.832, -780...  2408.553136
# 20  MULTIPOLYGON (((-8465666.158 4243560.215, -846...  1318.248889
# 21  MULTIPOLYGON (((-7884469.880 4631120.914, -788...  1977.266908
# 22  MULTIPOLYGON (((-9554101.607 5054383.111, -955...  1296.517501
# 23  POLYGON ((-10264179.251 5199070.062, -10264290...  1720.691114
# 24  MULTIPOLYGON (((-9918079.384 3365384.908, -991...   315.813389
# 25  POLYGON ((-9968104.471 4044995.075, -9969822.4...   883.738203
# 26  POLYGON ((-11692821.758 5009415.491, -11697074...  2994.237361
# 27  POLYGON ((-11583154.694 4564255.638, -11583144...  1742.015531
# 28  POLYGON ((-12695113.510 4564090.885, -12695228...  3399.843139
# 29  POLYGON ((-8065330.879 4804706.628, -8065305.0...  2086.480424
# 30  POLYGON ((-8372436.418 4437830.426, -8372386.2...  1584.938787
# 31  POLYGON ((-11799643.719 3562482.857, -11810970...  2153.910133
# 32  MULTIPOLYGON (((-8242190.833 4530716.300, -824...  1693.013986
# 33  MULTIPOLYGON (((-8432870.545 3918402.884, -843...   886.327702
# 34  POLYGON ((-10989947.154 5113871.133, -11009990...  2228.863976
# 35  MULTIPOLYGON (((-9221163.156 4643021.413, -922...   948.594888
# 36  POLYGON ((-10791824.732 3779209.549, -10792682...  1228.900436
# 37  POLYGON ((-13572321.228 5081632.675, -13570766...  3954.203143
# 38  POLYGON ((-8896227.462 4421709.583, -8914013.6...  1349.089039
# 39  MULTIPOLYGON (((-7946384.445 4615838.418, -794...  1967.284957
# 40  POLYGON ((-8826606.360 3685794.017, -8826699.5...   672.044326
# 41  POLYGON ((-11583292.508 4918137.516, -11583392...  1976.522341
# 42  POLYGON ((-9292072.558 4073991.019, -9281251.8...   344.144784
# 43  MULTIPOLYGON (((-10812947.048 3105405.139, -10...  1401.946378
# 44  POLYGON ((-12361645.512 4592120.019, -12361664...  2860.297168
# 45  POLYGON ((-8063293.287 4812675.434, -8063367.8...  2016.163482
# 46  MULTIPOLYGON (((-8457343.245 4211863.882, -845...  1036.536417
# 47  MULTIPOLYGON (((-13638812.248 5375430.526, -13...  4080.279079
# 48  POLYGON ((-8914013.645 4421760.456, -8896227.4...   950.298848
# 49  MULTIPOLYGON (((-10063649.990 5234987.518, -10...  1365.831817
# 50  POLYGON ((-12250540.311 4563826.946, -12258684...  2571.664029
#
#        rain_min     rain_max    rain_mean  rain_count
# 0   1148.892090  2756.134033  1706.379871        7442
# 2     58.065002   983.212036   241.176297       16631
# 3    834.419067  1702.319092  1307.564803        7762
# 4     35.570004  5572.697266   761.214628       24009
# 5    133.687012  1926.190063   509.372574       16233
# 6   1059.968018  1371.348022  1179.953164         798
# 7   1024.367065  1418.944092  1179.041502         317
# 8    978.206055  1113.288086  1036.165661          11
# 9    917.110046  2640.752197  1600.758271        7980
# 10   925.679016  2125.678223  1311.451380        8443
# 12   174.809006  2433.842041   754.185243       14068
# 13   714.211060  1379.985107   973.250028        8887
# 14   869.397034  1557.886108  1191.828108        5678
# 15   610.139038  1219.569092   834.973661        9169
# 16   426.167023  1468.852051   779.584040       12845
# 17   899.188049  1582.967041  1297.543677        6136
# 18   912.208069  2615.435059  1660.091140        6693
# 19   815.597046  1788.377075  1174.943024        5634
# 20   792.915039  1604.505127  1114.284314        1632
# 21  1041.555054  1566.132080  1222.947541        1332
# 22   806.529053  1425.137085  1042.026385        9816
# 23   314.930023  1242.421021   742.829691       14644
# 24  1010.153076  2849.452148  1564.714641        6830
# 25   692.847046  1580.586060  1085.026233       10750
# 26    97.147003  2678.886230   459.611274       25846
# 27   374.388031  1195.865112   668.197051       12342
# 28    41.699001  2417.118164   292.483321       17147
# 29  1035.072021  2066.110107  1318.293738        1549
# 30  1013.220032  1437.503052  1187.568694        1221
# 31   172.302002  1223.369019   405.931262       17763
# 32   833.245056  2006.856079  1259.132034        8104
# 33   763.143066  2261.467041  1272.379589        7437
# 34   158.985001   657.812012   360.642517       12588
# 35   884.398071  1485.986084  1171.597305        6531
# 36   536.785034  1547.705078   971.299382       10348
# 37   172.416016  6110.413086   965.097099       16272
# 38   879.666016  1873.695068  1188.730914        7165
# 39  1026.144043  1396.014038  1277.760532         181
# 40   902.894043  2099.670166  1257.020392        4536
# 41   228.146011   865.870056   467.303419       13043
# 42   865.494019  2118.056152  1451.505618        6319
# 43   179.419006  2921.028076   800.035881       37569
# 44    95.682007  1929.757080   342.278457       13178
# 45   962.443054  1792.696045  1253.885853        1624
# 46   739.064026  1622.084106  1071.215183        6132
# 47   198.931015  8375.414062  1291.735830       12121
# 48   772.546021  1739.305054  1216.903980        3744
# 49   692.764038  1308.535034   984.828935        9511
# 50   172.786011  2616.621094   500.118654       16131

# %%
f,a = plt.subplots(figsize=(10,3))

country_rain.plot(column="rain_mean",cmap="Blues",legend=True,ax=a,edgecolor="black")
# Out:
# <Axes: >

# %% [markdown]
# ### With counties

# %%
# Read in file
counties = geopandas.read_file(data_dir+"us_counties_2017.shp")

# Reproject
counties = counties.to_crs(country_proj.crs)

counties.plot()
# Out:
# <Axes: >

# %% [markdown]
# Subset to Illinois:

# %%
IL_counties = counties[counties['STATEFP'] == "17"]

IL_counties.plot()
# Out:
# <Axes: >

# %% [markdown]
# Now do the rasterstats as before.

# %%
from rasterstats import zonal_stats

zonal_stats(IL_counties, "./ppt_reproj.tif")
# Out:
# [{'min': 1079.4630126953125,
#   'max': 1349.717041015625,
#   'mean': 1243.9564426369864,
#   'count': 73},
#  {'min': 716.6260375976562,
#   'max': 895.7780151367188,
#   'mean': 806.95,
#   'count': 90},
#  {'min': 996.6900634765625,
#   'max': 1265.758056640625,
#   'mean': 1113.7713994565217,
#   'count': 138},
#  {'min': 812.3440551757812,
#   'max': 979.0570678710938,
#   'mean': 878.5792410714286,
#   'count': 70},
#  {'min': 1028.9639892578125,
#   'max': 1229.988037109375,
#   'mean': 1139.410887096774,
#   'count': 155},
#  {'min': 845.7640380859375,
#   'max': 1053.7969970703125,
#   'mean': 938.0377604166666,
#   'count': 33},
#  {'min': 807.800048828125,
#   'max': 967.9600219726562,
#   'mean': 898.7641256313132,
#   'count': 99},
#  {'min': 752.60205078125,
#   'max': 854.655029296875,
#   'mean': 803.3509615384615,
#   'count': 52},
#  {'min': 869.3130493164062,
#   'max': 1003.6940307617188,
#   'mean': 927.1631324404761,
#   'count': 42},
#  {'min': 856.4390258789062,
#   'max': 989.9580688476562,
#   'mean': 897.3748739919355,
#   'count': 31},
#  {'min': 818.864013671875,
#   'max': 944.2110595703125,
#   'mean': 881.6570490056819,
#   'count': 88},
#  {'min': 754.3650512695312,
#   'max': 872.1060180664062,
#   'mean': 796.7673828125,
#   'count': 40},
#  {'min': 743.6600341796875,
#   'max': 873.2290649414062,
#   'mean': 816.0295138888889,
#   'count': 63},
#  {'min': 972.5880737304688,
#   'max': 1119.830078125,
#   'mean': 1054.143322172619,
#   'count': 42},
#  {'min': 809.6010131835938,
#   'max': 1040.9820556640625,
#   'mean': 914.417206554878,
#   'count': 82},
#  {'min': 783.5640258789062,
#   'max': 961.7470703125,
#   'mean': 869.0125,
#   'count': 100},
#  {'min': 822.779052734375,
#   'max': 1017.278076171875,
#   'mean': 940.9737215909091,
#   'count': 88},
#  {'min': 741.2760620117188,
#   'max': 904.7530517578125,
#   'mean': 838.6522090517242,
#   'count': 87},
#  {'min': 814.468017578125,
#   'max': 1093.5760498046875,
#   'mean': 954.2574474299065,
#   'count': 107},
#  {'min': 870.2250366210938,
#   'max': 1276.089111328125,
#   'mean': 1052.6260016025642,
#   'count': 78},
#  {'min': 766.9810180664062,
#   'max': 1031.3370361328125,
#   'mean': 902.4500113224638,
#   'count': 138},
#  {'min': 971.968017578125,
#   'max': 1099.162109375,
#   'mean': 1024.4858072916666,
#   'count': 60},
#  {'min': 852.6350708007812,
#   'max': 1077.364013671875,
#   'mean': 947.9448198198198,
#   'count': 111},
#  {'min': 975.1660766601562,
#   'max': 1164.1680908203125,
#   'mean': 1074.370868389423,
#   'count': 104},
#  {'min': 927.0280151367188,
#   'max': 1276.4400634765625,
#   'mean': 1050.6207890070923,
#   'count': 141},
#  {'min': 784.0210571289062,
#   'max': 943.27001953125,
#   'mean': 864.7443359375,
#   'count': 80},
#  {'min': 846.8510131835938,
#   'max': 1098.93603515625,
#   'mean': 958.729872881356,
#   'count': 59},
#  {'min': 915.8700561523438,
#   'max': 1168.947998046875,
#   'mean': 1052.1204470198675,
#   'count': 151},
#  {'min': 915.2330322265625,
#   'max': 1083.2919921875,
#   'mean': 997.7974411231884,
#   'count': 69},
#  {'min': 781.9480590820312,
#   'max': 927.114013671875,
#   'mean': 847.0297448394496,
#   'count': 109},
#  {'min': 840.7570190429688,
#   'max': 1043.1361083984375,
#   'mean': 959.3763844936709,
#   'count': 79},
#  {'min': 836.2000122070312,
#   'max': 1106.1500244140625,
#   'mean': 997.7436655405405,
#   'count': 74},
#  {'min': 967.6090698242188,
#   'max': 1087.945068359375,
#   'mean': 1034.1851222826087,
#   'count': 46},
#  {'min': 980.0040283203125,
#   'max': 1149.9910888671875,
#   'mean': 1042.1501850328948,
#   'count': 76},
#  {'min': 767.0460205078125,
#   'max': 1004.3660278320312,
#   'mean': 876.2727531934306,
#   'count': 137},
#  {'min': 768.0950317382812,
#   'max': 1139.1630859375,
#   'mean': 964.2501116071429,
#   'count': 140},
#  {'min': 994.8140258789062,
#   'max': 1147.51806640625,
#   'mean': 1052.2741477272727,
#   'count': 110},
#  {'min': 865.091064453125,
#   'max': 1361.947021484375,
#   'mean': 1085.4632554945056,
#   'count': 182},
#  {'min': 992.5950317382812,
#   'max': 1147.3060302734375,
#   'mean': 1077.444897676991,
#   'count': 113},
#  {'min': 828.3400268554688,
#   'max': 1081.0050048828125,
#   'mean': 938.9670758928571,
#   'count': 168},
#  {'min': 739.5960083007812,
#   'max': 951.0010375976562,
#   'mean': 822.6278994845361,
#   'count': 194},
#  {'min': 852.7210693359375,
#   'max': 1021.0690307617188,
#   'mean': 936.2184132543103,
#   'count': 58},
#  {'min': 791.9340209960938,
#   'max': 917.0110473632812,
#   'mean': 870.2533299180328,
#   'count': 61},
#  {'min': 714.2110595703125,
#   'max': 910.3070678710938,
#   'mean': 794.8961292613636,
#   'count': 88},
#  {'min': 979.2330322265625,
#   'max': 1195.9000244140625,
#   'mean': 1088.7071953781513,
#   'count': 119},
#  {'min': 761.8580322265625,
#   'max': 916.18505859375,
#   'mean': 835.4970206567797,
#   'count': 59},
#  {'min': 1034.77001953125,
#   'max': 1197.18701171875,
#   'mean': 1104.102570564516,
#   'count': 62},
#  {'min': 783.259033203125,
#   'max': 1083.382080078125,
#   'mean': 943.2521001344086,
#   'count': 93},
#  {'min': 966.8660278320312,
#   'max': 1123.8050537109375,
#   'mean': 1029.2498629385964,
#   'count': 57},
#  {'min': 741.68701171875,
#   'max': 929.8480224609375,
#   'mean': 817.9478786496351,
#   'count': 137},
#  {'min': 769.1200561523438,
#   'max': 937.4230346679688,
#   'mean': 864.7153596698113,
#   'count': 106},
#  {'min': 966.6290283203125,
#   'max': 1223.3360595703125,
#   'mean': 1107.6278645833333,
#   'count': 60},
#  {'min': 827.7980346679688,
#   'max': 1018.1280517578125,
#   'mean': 922.26171875,
#   'count': 104},
#  {'min': 904.1260375976562,
#   'max': 1076.7659912109375,
#   'mean': 1011.7270089285714,
#   'count': 105},
#  {'min': 767.0630493164062,
#   'max': 957.4010620117188,
#   'mean': 851.9288194444445,
#   'count': 90},
#  {'min': 810.864013671875,
#   'max': 987.9310302734375,
#   'mean': 927.4579190340909,
#   'count': 44},
#  {'min': 749.7960205078125,
#   'max': 939.4840698242188,
#   'mean': 848.2493055555556,
#   'count': 45},
#  {'min': 794.623046875,
#   'max': 1065.2510986328125,
#   'mean': 915.9988982371794,
#   'count': 156},
#  {'min': 1016.9950561523438,
#   'max': 1179.4970703125,
#   'mean': 1084.1587540064102,
#   'count': 78},
#  {'min': 962.22607421875,
#   'max': 1124.791015625,
#   'mean': 1025.8656023550725,
#   'count': 69},
#  {'min': 854.5250244140625,
#   'max': 1008.3380737304688,
#   'mean': 922.2233072916666,
#   'count': 72},
#  {'min': 873.322021484375,
#   'max': 1032.14501953125,
#   'mean': 972.0370133196722,
#   'count': 122},
#  {'min': 876.0540161132812,
#   'max': 1186.537109375,
#   'mean': 1036.5805864726028,
#   'count': 73},
#  {'min': 795.9090576171875,
#   'max': 962.4940185546875,
#   'mean': 883.4361245598592,
#   'count': 142},
#  {'min': 794.612060546875,
#   'max': 925.947021484375,
#   'mean': 834.4231617647059,
#   'count': 85},
#  {'min': 991.56005859375,
#   'max': 1092.6270751953125,
#   'mean': 1059.4978966346155,
#   'count': 26},
#  {'min': 779.3300170898438,
#   'max': 935.2860717773438,
#   'mean': 859.0238715277778,
#   'count': 63},
#  {'min': 1010.7440185546875,
#   'max': 1379.985107421875,
#   'mean': 1170.7207661290322,
#   'count': 186},
#  {'min': 882.0860595703125,
#   'max': 1100.9830322265625,
#   'mean': 990.8811910377359,
#   'count': 106},
#  {'min': 1003.946044921875,
#   'max': 1262.30908203125,
#   'mean': 1129.6566310975609,
#   'count': 82},
#  {'min': 865.6590576171875,
#   'max': 1290.3070068359375,
#   'mean': 1084.3864524147727,
#   'count': 88},
#  {'min': 762.0420532226562,
#   'max': 1028.10107421875,
#   'mean': 894.7531960227273,
#   'count': 110},
#  {'min': 786.2040405273438,
#   'max': 1127.3570556640625,
#   'mean': 926.4011145104895,
#   'count': 143},
#  {'min': 793.904052734375,
#   'max': 979.6390380859375,
#   'mean': 890.742770522388,
#   'count': 134},
#  {'min': 724.7680053710938,
#   'max': 807.1600341796875,
#   'mean': 758.9604577850877,
#   'count': 57},
#  {'min': 1045.9600830078125,
#   'max': 1191.0020751953125,
#   'mean': 1131.9228707107843,
#   'count': 51},
#  {'min': 742.175048828125,
#   'max': 954.1320190429688,
#   'mean': 863.5169771634615,
#   'count': 104},
#  {'min': 886.3650512695312,
#   'max': 1093.4000244140625,
#   'mean': 992.7027803308823,
#   'count': 68},
#  {'min': 921.0050659179688,
#   'max': 1088.8060302734375,
#   'mean': 995.7509191176471,
#   'count': 85},
#  {'min': 774.1320190429688,
#   'max': 880.4270629882812,
#   'mean': 824.5558733258929,
#   'count': 56},
#  {'min': 1073.9200439453125,
#   'max': 1250.7080078125,
#   'mean': 1161.5072428385417,
#   'count': 96},
#  {'min': 901.3860473632812,
#   'max': 996.404052734375,
#   'mean': 948.4432246767242,
#   'count': 58},
#  {'min': 891.1530151367188,
#   'max': 1067.4600830078125,
#   'mean': 986.6841947115385,
#   'count': 78},
#  {'min': 965.4410400390625,
#   'max': 1126.72802734375,
#   'mean': 1043.9274088541667,
#   'count': 48},
#  {'min': 910.5160522460938,
#   'max': 1023.3460693359375,
#   'mean': 986.1583426339286,
#   'count': 56},
#  {'min': 961.5850219726562,
#   'max': 1350.3970947265625,
#   'mean': 1124.0787760416667,
#   'count': 96},
#  {'min': 1032.14599609375,
#   'max': 1266.9610595703125,
#   'mean': 1163.7526041666667,
#   'count': 48},
#  {'min': 894.6060180664062,
#   'max': 1060.4410400390625,
#   'mean': 976.1309678819445,
#   'count': 72},
#  {'min': 1087.238037109375,
#   'max': 1312.677001953125,
#   'mean': 1175.9342830882354,
#   'count': 51},
#  {'min': 1087.361083984375,
#   'max': 1258.6240234375,
#   'mean': 1173.28916015625,
#   'count': 40},
#  {'min': 791.697021484375,
#   'max': 1051.9610595703125,
#   'mean': 932.423216540404,
#   'count': 99},
#  {'min': 975.967041015625,
#   'max': 1254.925048828125,
#   'mean': 1124.5659855769231,
#   'count': 65},
#  {'min': 1006.695068359375,
#   'max': 1275.7490234375,
#   'mean': 1092.5972842261904,
#   'count': 84},
#  {'min': 890.1500244140625,
#   'max': 1087.6910400390625,
#   'mean': 979.8598860981308,
#   'count': 107},
#  {'min': 944.0240478515625,
#   'max': 1204.2191162109375,
#   'mean': 1070.5146484375,
#   'count': 80},
#  {'min': 820.7290649414062,
#   'max': 982.6690673828125,
#   'mean': 919.0164995335821,
#   'count': 67},
#  {'min': 771.3720092773438,
#   'max': 1122.39208984375,
#   'mean': 982.4366629464286,
#   'count': 112},
#  {'min': 956.1620483398438,
#   'max': 1098.5450439453125,
#   'mean': 1042.5260836693549,
#   'count': 31},
#  {'min': 1006.7650756835938,
#   'max': 1272.614013671875,
#   'mean': 1150.9391084558824,
#   'count': 51},
#  {'min': 830.2230224609375,
#   'max': 1000.1050415039062,
#   'mean': 914.3853515625,
#   'count': 80},
#  {'min': 812.5470581054688,
#   'max': 1015.9370727539062,
#   'mean': 903.8506181318681,
#   'count': 91},
#  {'min': 1063.030029296875,
#   'max': 1115.319091796875,
#   'mean': 1085.2293346774193,
#   'count': 31}]

# %%
county_rain_stats = pd.DataFrame(zonal_stats(IL_counties, "./ppt_reproj.tif"))

county_rain_stats.columns = ["rain_"+x for x in county_rain_stats.columns]

# Note: you need to make the indices match first
county_rain_stats.index = IL_counties.index

IL_counties = pd.concat([IL_counties,county_rain_stats],axis=1)

# %%
f,a = plt.subplots(figsize=(6,3))

IL_counties.plot(column="rain_mean",cmap="Blues",legend=True,ax=a,edgecolor="black")
# Out:
# <Axes: >

# %% [markdown]
# Simple as that!
